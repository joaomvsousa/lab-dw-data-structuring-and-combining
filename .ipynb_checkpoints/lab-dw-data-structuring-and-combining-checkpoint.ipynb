# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

# %%
url1="https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
url2="https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
url3="https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"

dp1=pd.read_csv(url1)
dp2=pd.read_csv(url2)
dp3=pd.read_csv(url3)

# %%
dp1.rename(columns={"ST": "state", "GENDER": "Gender"}, inplace=True)
dp2.rename(columns={"ST": "state", "GENDER": "Gender"}, inplace=True)
dp3.rename(columns={"State": "state"}, inplace=True)

# %%
display(dp1)
display(dp2)
display(dp3)
# Out:
#      Customer       state Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
company = pd.concat([dp1, dp2, dp3], ignore_index=True)

# %%
insurance = company.copy()

# %%
insurance_company = company.copy()

# %%
def lower_names_spaces(insurance):
    insurance.columns = insurance.columns.str.lower()
    insurance.columns = insurance.columns.str.replace(" ", "_")
    return insurance

# %%
lower_names_spaces(insurance)
# Out:
#       customer       state gender             education  \
# 0      RB50392  WASHINGTON    NaN                Master
# 1      QZ44356     ARIZONA      F              Bachelor
# 2      AI49188      NEVADA      F              Bachelor
# 3      WW63253  CALIFORNIA      M              Bachelor
# 4      GA49547  WASHINGTON      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  CALIFORNIA      M              Bachelor
# 12070  PK87824  CALIFORNIA      F               College
# 12071  TD14365  CALIFORNIA      M              Bachelor
# 12072  UP19263  CALIFORNIA      M               College
# 12073  Y167826  CALIFORNIA      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59       0.0                  94.0
# 2                 1288743.17   48767.0                 108.0
# ...

# %%
insurance.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
insurance["state"].value_counts()
# Out:
# state
# CALIFORNIA    3032
# OREGON        2601
# ARIZONA       1704
# NEVADA         882
# WASHINGTON     798
# CALI           120
# Name: count, dtype: int64

# %%
# cleaning column state, first replacing short names and after put everything uppercase
insurance["state"] = insurance["state"].replace("WA", "WASHINGTON")
insurance["state"] = insurance["state"].replace("AZ", "ARIZONA")
insurance["state"] = insurance["state"].replace("CALI", "CALIFORNIA")
insurance["state"] = insurance["state"].str.upper()

# %%
#cleaning column gender, transforming all data who isn't M or F in it. 
insurance["gender"] = insurance["gender"].replace("Male", "M")
insurance["gender"] = insurance["gender"].replace("female", "F")
insurance["gender"] = insurance["gender"].replace("Femal", "F")

# %%
insurance["gender"].unique()
# Out:
# array([nan, 'F', 'M'], dtype=object)

# %%
insurance["education"] = insurance["education"].replace("Bachelors", "Bachelor")

# %%
insurance["education"].unique()
# Out:
# array(['Master', 'Bachelor', 'High School or Below', 'College', 'Doctor',
#        nan], dtype=object)

# %%
test9 = insurance.copy()

# %%
insurance["customer_lifetime_value"] = insurance["customer_lifetime_value"].apply(
    lambda x: x.replace("%", " ") if isinstance(x, str) else x)

# %%
insurance.reset_index(drop=True)
# Out:
#       customer       state gender             education  \
# 0      RB50392  WASHINGTON    NaN                Master
# 1      QZ44356     ARIZONA      F              Bachelor
# 2      AI49188      NEVADA      F              Bachelor
# 3      WW63253  CALIFORNIA      M              Bachelor
# 4      GA49547  WASHINGTON      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  CALIFORNIA      M              Bachelor
# 12070  PK87824  CALIFORNIA      F               College
# 12071  TD14365  CALIFORNIA      M              Bachelor
# 12072  UP19263  CALIFORNIA      M               College
# 12073  Y167826  CALIFORNIA      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59       0.0                  94.0
# 2                 1288743.17   48767.0                 108.0
# ...

# %%
insurance["number_of_open_complaints"].unique()
# Out:
# array(['1/0/00', '1/2/00', '1/1/00', '1/3/00', '1/5/00', '1/4/00', nan, 0,
#        2, 3, 1, 5, 4], dtype=object)

# %%
def extract_middle_number(string):
    if isinstance(string, str) and string.count('/') == 2:  # Check if the value is a string and contains two slashes
        parts = string.split('/')  # Split the string by '/'
        if len(parts) == 3:  # Check if the string has three parts
            middle_part = parts[1]  # Get the middle part
            if middle_part.isdigit():  # Check if the middle part is composed of digits
                return middle_part  # Return the middle part
    return string  # Return the original value if the conditions are not met

# %%
insurance['number_of_open_complaints'] = insurance['number_of_open_complaints'].apply(extract_middle_number)

# %%
insurance['number_of_open_complaints'].value_counts()
# Out:
# number_of_open_complaints
# 0    5629
# 0    1626
# 1     765
# 2     283
# 1     247
# 3     230
# 4     119
# 2      93
# 3      60
# 5      44
# 4      29
# 5      12
# Name: count, dtype: int64

# %%
insurance["vehicle_class"] = insurance["vehicle_class"].replace("Sports Car", "Luxury")
insurance["vehicle_class"] = insurance["vehicle_class"].replace("Luxury SUV", "Luxury")
insurance["vehicle_class"] = insurance["vehicle_class"].replace("Luxury Car", "Luxury")

# %%
def drop_rows_with_many_missing_values(insurance, threshold=8):
    missing_counts = insurance.isnull().sum(axis=1)
    filtered_df = insurance[missing_counts <= threshold]
    return filtered_df

# %%
insurance_1 = drop_rows_with_many_missing_values(insurance)

# %%
insurance
# Out:
#       customer       state gender             education  \
# 0      RB50392  WASHINGTON    NaN                Master
# 1      QZ44356     ARIZONA      F              Bachelor
# 2      AI49188      NEVADA      F              Bachelor
# 3      WW63253  CALIFORNIA      M              Bachelor
# 4      GA49547  WASHINGTON      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  CALIFORNIA      M              Bachelor
# 12070  PK87824  CALIFORNIA      F               College
# 12071  TD14365  CALIFORNIA      M              Bachelor
# 12072  UP19263  CALIFORNIA      M               College
# 12073  Y167826  CALIFORNIA      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59       0.0                  94.0
# 2                 1288743.17   48767.0                 108.0
# ...

# %%
insurance["gender"].isnull()
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12069    False
# 12070    False
# 12071    False
# 12072    False
# 12073    False
# Name: gender, Length: 12074, dtype: bool

# %%
test20 = insurance_1.copy()

# %%
insurance['gender'] = insurance['gender'].fillna(method='bfill')
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_884/1999993452.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   insurance['gender'] = insurance['gender'].fillna(method='bfill')

# %%
insurance["gender"].isnull().unique()
# Out:
# array([False])

# %%
insurance['customer_lifetime_value'] = insurance['customer_lifetime_value'].astype(float)

# %%
insurance['customer_lifetime_value'].describe()
# Out:
# count    9.130000e+03
# mean     1.821964e+05
# std      4.410502e+05
# min      1.898008e+03
# 25%      4.650064e+03
# 50%      7.714877e+03
# 75%      2.619741e+04
# max      5.816655e+06
# Name: customer_lifetime_value, dtype: float64

# %%
mean_value = insurance['customer_lifetime_value'].mean()

# %%
insurance['customer_lifetime_value'] = insurance['customer_lifetime_value'].fillna(mean_value)

# %%
insurance["customer_lifetime_value"].isnull().unique()
# Out:
# array([False])

# %%
test30 = insurance.copy()

# %%
mean_value_income = insurance['income'].mean()

insurance['income'] = insurance['income'].fillna(mean_value_income)

# %%
# Out:
#       customer       state gender             education  \
# 0      RB50392  WASHINGTON      F                Master
# 1      QZ44356     ARIZONA      F              Bachelor
# 2      AI49188      NEVADA      F              Bachelor
# 3      WW63253  CALIFORNIA      M              Bachelor
# 4      GA49547  WASHINGTON      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  CALIFORNIA      M              Bachelor
# 12070  PK87824  CALIFORNIA      F               College
# 12071  TD14365  CALIFORNIA      M              Bachelor
# 12072  UP19263  CALIFORNIA      M               College
# 12073  Y167826  CALIFORNIA      M               College
#
#        customer_lifetime_value   income  monthly_premium_auto  \
# 0                 1.821964e+05      0.0                1000.0
# 1                 6.979536e+05      0.0                  94.0
# 2                 1.288743e+06  48767.0                 108.0
# ...

# %%
insurance['customer_lifetime_value'] = insurance['customer_lifetime_value'].astype(float)

# %%
insurance
# Out:
#       customer       state gender             education  \
# 0      RB50392  WASHINGTON      F                Master
# 1      QZ44356     ARIZONA      F              Bachelor
# 2      AI49188      NEVADA      F              Bachelor
# 3      WW63253  CALIFORNIA      M              Bachelor
# 4      GA49547  WASHINGTON      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  CALIFORNIA      M              Bachelor
# 12070  PK87824  CALIFORNIA      F               College
# 12071  TD14365  CALIFORNIA      M              Bachelor
# 12072  UP19263  CALIFORNIA      M               College
# 12073  Y167826  CALIFORNIA      M               College
#
#        customer_lifetime_value   income  monthly_premium_auto  \
# 0                 1.821964e+05      0.0                1000.0
# 1                 6.979536e+05      0.0                  94.0
# 2                 1.288743e+06  48767.0                 108.0
# ...

# %%
mean_value_customer_lifetime_value = insurance['customer_lifetime_value'].mean()

insurance['customer_lifetime_value'] = insurance['customer_lifetime_value'].fillna(mean_value_customer_lifetime_value)

# %%
insurance['vehicle_class'] = insurance['vehicle_class'].fillna(method='bfill')
# Out:
# /var/folders/d8/knczg5hs597_plsphx_dp9kh0000gn/T/ipykernel_884/4268540057.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   insurance['vehicle_class'] = insurance['vehicle_class'].fillna(method='bfill')

# %%
insurance['vehicle_class'].isnull().unique()
# Out:
# array([False])

# %%
mean_value_total_claim_amount = insurance['total_claim_amount'].mean()

insurance['total_claim_amount'] = insurance['total_claim_amount'].fillna(mean_value_customer_lifetime_value)

# %%
insurance['total_claim_amount'].isnull().unique()
# Out:
# array([False])

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url1="https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"

db=pd.read_csv(url1)

# %%
display(db)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
db.drop_duplicates(subset=["customer"], inplace=True)

# %%
db
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10904       10904  QI63521      Nevada             19228.463620       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# ...

# %%
db["sales_channel"].unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
db.dtypes
# Out:
# unnamed:_0                         int64
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# ...

# %%
test40= db.copy()

# %%
db.pivot(index="customer", columns="sales_channel", values="total_claim_amount")
# Out:
# sales_channel  Agent   Branch  Call Center      Web
# customer
# AA10041          NaN      NaN      1258.33      NaN
# AA11235          NaN   350.40          NaN      NaN
# AA16582        511.2      NaN          NaN      NaN
# AA30683          NaN      NaN          NaN   847.72
# AA34092          NaN      NaN          NaN  1152.00
# ...              ...      ...          ...      ...
# ZZ77357        468.0      NaN          NaN      NaN
# ZZ83340          NaN   315.00          NaN      NaN
# ZZ89380          NaN      NaN        47.06      NaN
# ZZ91716          NaN      NaN          NaN   491.76
# ZZ97035          NaN  2027.72          NaN      NaN
#
# [9134 rows x 4 columns]

# %%
db['total_claim_amount'] = db['total_claim_amount'].round(2)

# %%
db.pivot_table(index="customer", columns="sales_channel", values="total_claim_amount", aggfunc="sum")
# Out:
# sales_channel  Agent   Branch  Call Center      Web
# customer
# AA10041          NaN      NaN      1258.33      NaN
# AA11235          NaN   350.40          NaN      NaN
# AA16582        511.2      NaN          NaN      NaN
# AA30683          NaN      NaN          NaN   847.72
# AA34092          NaN      NaN          NaN  1152.00
# ...              ...      ...          ...      ...
# ZZ77357        468.0      NaN          NaN      NaN
# ZZ83340          NaN   315.00          NaN      NaN
# ZZ89380          NaN      NaN        47.06      NaN
# ZZ91716          NaN      NaN          NaN   491.76
# ZZ97035          NaN  2027.72          NaN      NaN
#
# [9134 rows x 4 columns]

# %%
pivot_table_counts = db.pivot_table(index="customer", columns="sales_channel", values="total_claim_amount", aggfunc="count", fill_value=0)
column_counts = pivot_table_counts.sum(axis=0)

# %%
column_counts
# Out:
# sales_channel
# Agent          3477
# Branch         2567
# Call Center    1765
# Web            1325
# dtype: int64

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
db["education"].isnull().unique()
# Out:
# array([False])

# %%
db["gender"].isnull().unique()
# Out:
# array([False])

# %%
db["customer_lifetime_value"].isnull().unique()
# Out:
# array([False])

# %%
pivot_table = db.pivot_table(index="gender", columns="education", values="customer_lifetime_value", aggfunc="mean")

# %%
pivot_table
# Out:
# education     Bachelor      College       Doctor  High School or Below  \
# gender
# F          8012.877921  7732.833339  7423.630380            8578.99584
# M          7722.072099  7971.342089  7614.823122            8010.08269
#
# education       Master
# gender
# F          8319.111562
# M          8158.078485

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
